# %%
import requests
import pandas as pd

url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1&sort_by=popularity.desc"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIwZGQxZjA4MzI2YzcyZjQ2NTJjOTdiYzMzOWU5ZWY5OCIsInN1YiI6IjYzZmNjYTFlMzQ0YThlMDA4ZWM2NjBmNiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.osagCC7I6zr1OyfQmXr6JOpf_8qG7dvnAtu1k375XFI"
}

response = requests.get(url, headers=headers).json()

# %%
 response['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/iIvQnZyzgx9TkbrOgcXx0p7aLiq.jpg',
#   'genre_ids': [27, 53],
#   'id': 1008042,
#   'original_language': 'en',
#   'original_title': 'Talk to Me',
#   'overview': 'When a group of friends discover how to conjure spirits using an embalmed hand, they become hooked on the new thrill, until one of them goes too far and unleashes terrifying supernatural forces.',
#   'popularity': 2019.964,
#   'poster_path': '/kdPMUMJzyYAc4roD52qavX0nLIC.jpg',
#   'release_date': '2023-07-26',
#   'title': 'Talk to Me',
#   'video': False,
#   'vote_average': 7.2,
#   'vote_count': 712},
#  {'adult': False,
#   'backdrop_path': '/4XM8DUTQb3lhLemJC51Jx4a2EuA.jpg',
#   'genre_ids': [28, 80, 53],
#   'id': 385687,
#   'original_language': 'en',
#   'original_title': 'Fast X',
# ...

# %%
###'popularity': 1763.378,
### 'poster_path': '/fiVW06jE7z9YnO4trhaMEdclSiC.jpg',
###  'release_date': '2023-05-17',
### 'title': 'Fast X',
### 'vote_average': 7.3,
##  'vote_count': 3759},
### 'overview'
popularity =[]
poster_path =[]
release_date =[]
title =[]
vote_avg =[]
vote_count =[]
overview= []


for i in response['results']:
        popularity.append(i['popularity'])
        poster_path.append(i['poster_path'])
        release_date.append(i['release_date'])
        title.append(i['title'])
        vote_avg.append(i['vote_average'])
        vote_count.append(i['vote_count'])
        overview.append(i['overview'])


d={'title':title,'overview':overview,'release_date':release_date,'popularity':popularity,'vote_avg':vote_avg,'vote_count':vote_count,'release_date':release_date}
    
df= pd.DataFrame(d)

df
# Out:
#                                           title  \
# 0                                    Talk to Me
# 1                                        Fast X
# 2                                        Barbie
# 3                             Meg 2: The Trench
# 4                                   Blue Beetle
# 5                                    The Nun II
# 6                                      Kandahar
# 7                                   Retribution
# 8                                     Elemental
# 9         Indiana Jones and the Dial of Destiny
# 10                             Sound of Freedom
# 11             Transformers: Rise of the Beasts
# 12                             After Everything
# 13          Spider-Man: Across the Spider-Verse
# 14  Teenage Mutant Ninja Turtles: Mutant Mayhem
# 15                                     Red Dawn
# 16                                        Sakra
# 17                                    The Flash
# ...

# %%
 df.shape
# Out:
# (20, 6)
